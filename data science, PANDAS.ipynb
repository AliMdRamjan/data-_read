# %%
print("222222222222abvbbbb2222222<*4444444444444+5555555555")
# Out:
# 222222222222abvbbbb2222222<*4444444444444+5555555555

# %%
import numpy as np
import pandas as mahdi
# 1).Object creation😁
s1 = mahdi.Series([1, 2, 3, 4, np.nan,5, 6, 7, 8, 1.000000002, 8])
int_num = mahdi.Series([1, 2, 3, 4])
print(type(int_num))
# Out:
# <class 'pandas.core.series.Series'>

# %%
s1 = pd.Series([1, 2, 3, 4, np.nan,5, 6, 7, 8, 1.000000002, 8])
s2 = pd.Series([1, 2, 3, 4, np.nan,5, 6, 7888888+777*99999, 8, 1.000000002, 8])
s2
s1
s1
s2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-118fd51b0970> in <module>
# ----> 1 s1 = pd.Series([1, 2, 3, 4, np.nan,5, 6, 7, 8, 1.000000002, 8])
#       2 s2 = pd.Series([1, 2, 3, 4, np.nan,5, 6, 7888888+777*99999, 8, 1.000000002, 8])
#       3 s2
#       4 s1
#       5 s1
#
# NameError: name 'pd' is not defined

# %%
s1 = pd.Series([1, 2, 3, 4, np.nan,5, 6, 7, 8, 1.000000002, 8])
s2 = pd.Series([1, 2, 3, 4, np.nan,5, 6, 7888888+777*99999, 8, 1.000000002, 8])
s1/s2
# Out:
# 0     1.000000e+00
# 1     1.000000e+00
# 2     1.000000e+00
# 3     1.000000e+00
# 4              NaN
# 5     1.000000e+00
# 6     1.000000e+00
# 7     8.178706e-08
# 8     1.000000e+00
# 9     1.000000e+00
# 10    1.000000e+00
# dtype: float64

# %%
s1 = pd.Series([1, 2, 3, 4, np.nan,5, 6, 7, 8, 1.000000002, 8])
s2 = pd.Series([1, 2, 3, 4, np.nan,5, 6, 7888888+777*99999, 8, 1.000000002, 8])
(s1/s2)+(s1*s2)
# Out:
# 0             2.0
# 1             5.0
# 2            10.0
# 3            17.0
# 4             NaN
# 5            26.0
# 6            37.0
# 7     599116777.0
# 8            65.0
# 9             2.0
# 10           65.0
# dtype: float64

# %%
dates = pd.date_range("20210101", periods = 15)
dates
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10', '2021-01-11', '2021-01-12',
#                '2021-01-13', '2021-01-14', '2021-01-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(15, 7), index=dates, columns=list("ABCDEFG"))
df
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-01  0.323613 -0.736972  0.003152 -0.707786  0.233113  0.237354
# 2021-01-02 -0.678482  1.955107 -0.788801  1.157041  0.760486  0.286319
# 2021-01-03 -0.590769 -1.605737  1.749867 -0.207156 -0.601891  0.041785
# 2021-01-04  0.250947  1.503697  0.245543  0.273735 -0.051535  0.528398
# 2021-01-05 -1.033194 -1.348296 -0.539497 -0.384510 -1.143572 -0.757063
# 2021-01-06 -0.128781  0.342956 -2.756559  0.515014  1.406602  1.841216
# 2021-01-07 -0.259941 -1.234115 -1.909958  0.092016  0.217133 -0.714602
# 2021-01-08  0.520155 -1.159939  0.235535  0.599597 -1.516344  0.949098
# 2021-01-09 -2.207658 -0.144848 -1.189270  0.482793  1.434138 -0.042195
# 2021-01-10  0.279663  0.390494  0.711756  0.305323 -0.733493 -0.050262
# 2021-01-11 -0.866898  0.092457 -0.333655 -0.372080  1.776262  0.748067
# 2021-01-12  0.245868 -0.930582 -0.915743 -1.808666  1.210387  0.453452
# ...

# %%
df2 = pd.DataFrame(
...:     {
...:           "A": 1.0,
...:           "B": pd.Timestamp("20210101"),
...:           "C": pd.Series(1, index=list(range(4)), dtype="float32"),
...:           "D": np.array([3] * 4,  dtype="int32"),
...:           "E": pd.Categorical(["test", "train","test","train"]),
...:           "F": "fo",
...:     }
...:)
...:
df2
# Out:
#      A          B    C  D      E   F
# 0  1.0 2021-01-01  1.0  3   test  fo
# 1  1.0 2021-01-01  1.0  3  train  fo
# 2  1.0 2021-01-01  1.0  3   test  fo
# 3  1.0 2021-01-01  1.0  3  train  fo

# %%
df2.dtypes    #TAB 1)df.A,abs,add,add_prefix,add_suffix,align,
               #any,append,apply,applymap,B
             #2)df.bool,boxplot,C,clip,columns,copy,
           #count,combine,D,describe,diff,duplicated
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.describe
# Out:
# <bound method NDFrame.describe of      A          B    C  D      E   F
# 0  1.0 2021-01-01  1.0  3   test  fo
# 1  1.0 2021-01-01  1.0  3  train  fo
# 2  1.0 2021-01-01  1.0  3   test  fo
# 3  1.0 2021-01-01  1.0  3  train  fo>

# %%
#example
df2.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
df2.D
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# Name: D, dtype: int32

# %%
#### 2).viewing data😜
df.head (0)
# Out:
# Empty DataFrame
# Columns: [A, B, C, D, E, F, G]
# Index: []

# %%
df.head(3)
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-01  0.323613 -0.736972  0.003152 -0.707786  0.233113  0.237354
# 2021-01-02 -0.678482  1.955107 -0.788801  1.157041  0.760486  0.286319
# 2021-01-03 -0.590769 -1.605737  1.749867 -0.207156 -0.601891  0.041785
#
#                    G
# 2021-01-01 -1.888826
# 2021-01-02 -0.966348
# 2021-01-03 -0.865228

# %%
df.head(7)
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-01  0.323613 -0.736972  0.003152 -0.707786  0.233113  0.237354
# 2021-01-02 -0.678482  1.955107 -0.788801  1.157041  0.760486  0.286319
# 2021-01-03 -0.590769 -1.605737  1.749867 -0.207156 -0.601891  0.041785
# 2021-01-04  0.250947  1.503697  0.245543  0.273735 -0.051535  0.528398
# 2021-01-05 -1.033194 -1.348296 -0.539497 -0.384510 -1.143572 -0.757063
# 2021-01-06 -0.128781  0.342956 -2.756559  0.515014  1.406602  1.841216
# 2021-01-07 -0.259941 -1.234115 -1.909958  0.092016  0.217133 -0.714602
#
#                    G
# 2021-01-01 -1.888826
# 2021-01-02 -0.966348
# 2021-01-03 -0.865228
# 2021-01-04  1.416893
# 2021-01-05 -0.575588
# 2021-01-06  0.887801
# 2021-01-07  0.092244

# %%
df.tail(2)
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-14  1.498963  0.181241  0.145791  0.608643 -0.837329  1.485074
# 2021-01-15  0.088490  0.086556 -1.283679 -1.100699 -1.494143  1.262776
#
#                   G
# 2021-01-14  0.77196
# 2021-01-15 -0.54654

# %%
df.tail(8)
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-08  0.520155 -1.159939  0.235535  0.599597 -1.516344  0.949098
# 2021-01-09 -2.207658 -0.144848 -1.189270  0.482793  1.434138 -0.042195
# 2021-01-10  0.279663  0.390494  0.711756  0.305323 -0.733493 -0.050262
# 2021-01-11 -0.866898  0.092457 -0.333655 -0.372080  1.776262  0.748067
# 2021-01-12  0.245868 -0.930582 -0.915743 -1.808666  1.210387  0.453452
# 2021-01-13 -1.390649  1.076054  0.329621 -0.396533 -0.609607 -0.345756
# 2021-01-14  1.498963  0.181241  0.145791  0.608643 -0.837329  1.485074
# 2021-01-15  0.088490  0.086556 -1.283679 -1.100699 -1.494143  1.262776
#
#                    G
# 2021-01-08  0.152899
# 2021-01-09  1.953434
# 2021-01-10 -0.169646
# 2021-01-11 -1.576071
# 2021-01-12  0.966738
# 2021-01-13 -1.282759
# 2021-01-14  0.771960
# 2021-01-15 -0.546540

# %%
df.index
# Out:
# DatetimeIndex(['2021-01-01', '2021-01-02', '2021-01-03', '2021-01-04',
#                '2021-01-05', '2021-01-06', '2021-01-07', '2021-01-08',
#                '2021-01-09', '2021-01-10', '2021-01-11', '2021-01-12',
#                '2021-01-13', '2021-01-14', '2021-01-15'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G'], dtype='object')

# %%
#DataFrame.to_numpy() gives a NumPy representation of the underlying data.😜
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2021-01-01 00:00:00'), 1.0, 3, 'test', 'fo'],
#        [1.0, Timestamp('2021-01-01 00:00:00'), 1.0, 3, 'train', 'fo'],
#        [1.0, Timestamp('2021-01-01 00:00:00'), 1.0, 3, 'test', 'fo'],
#        [1.0, Timestamp('2021-01-01 00:00:00'), 1.0, 3, 'train', 'fo']],
#       dtype=object)

# %%
#For df,the DataFrame with multiple dtypes+,
#-DataFrame.to_numpy()is relatively expensive
df.to_numpy()
# Out:
# array([[ 0.32361318, -0.73697159,  0.00315169, -0.70778637,  0.23311325,
#          0.23735382, -1.88882604],
#        [-0.67848165,  1.95510727, -0.78880147,  1.15704103,  0.76048639,
#          0.28631881, -0.96634833],
#        [-0.5907686 , -1.60573748,  1.74986665, -0.20715573, -0.60189131,
#          0.04178525, -0.86522805],
#        [ 0.25094677,  1.50369651,  0.24554252,  0.27373466, -0.05153482,
#          0.52839844,  1.41689259],
#        [-1.03319407, -1.3482961 , -0.53949664, -0.38450974, -1.14357156,
#         -0.75706338, -0.57558833],
#        [-0.12878084,  0.342956  , -2.75655935,  0.51501436,  1.40660244,
#          1.84121598,  0.88780072],
#        [-0.25994097, -1.23411461, -1.90995846,  0.09201633,  0.21713258,
#         -0.71460201,  0.09224411],
#        [ 0.52015495, -1.1599388 ,  0.23553514,  0.59959731, -1.51634365,
#          0.94909781,  0.15289946],
#        [-2.20765774, -0.14484828, -1.1892703 ,  0.48279344,  1.43413789,
# ...

# %%
#DataFrame.to_numpy() does not include the index or column labels in the output.
#####describe() shows a quick statistic summary of your data:
df.describe()
# Out:
#                A          B          C          D          E          F  \
# count  15.000000  15.000000  15.000000  15.000000  15.000000  15.000000
# mean   -0.263245  -0.102128  -0.419727  -0.062884   0.003347   0.394911
# std     0.898901   1.072343   1.113030   0.763196   1.106806   0.762690
# min    -2.207658  -1.605737  -2.756559  -1.808666  -1.516344  -0.757063
# 25%    -0.772690  -1.045260  -1.052507  -0.390521  -0.785411  -0.046229
# 50%    -0.128781   0.086556  -0.333655   0.092016  -0.051535   0.286319
# 75%     0.265305   0.366725   0.240539   0.498904   0.985437   0.848582
# max     1.498963   1.955107   1.749867   1.157041   1.776262   1.841216
#
#                G
# count  15.000000
# mean   -0.108603
# std     1.135012
# min    -1.888826
# 25%    -0.915788
# 50%    -0.169646
# 75%     0.829880
# max     1.953434

# %%
#Transposing your data:😜
df.T
# Out:
#    2021-01-01  2021-01-02  2021-01-03  2021-01-04  2021-01-05  2021-01-06  \
# A    0.323613   -0.678482   -0.590769    0.250947   -1.033194   -0.128781
# B   -0.736972    1.955107   -1.605737    1.503697   -1.348296    0.342956
# C    0.003152   -0.788801    1.749867    0.245543   -0.539497   -2.756559
# D   -0.707786    1.157041   -0.207156    0.273735   -0.384510    0.515014
# E    0.233113    0.760486   -0.601891   -0.051535   -1.143572    1.406602
# F    0.237354    0.286319    0.041785    0.528398   -0.757063    1.841216
# G   -1.888826   -0.966348   -0.865228    1.416893   -0.575588    0.887801
#
#    2021-01-07  2021-01-08  2021-01-09  2021-01-10  2021-01-11  2021-01-12  \
# A   -0.259941    0.520155   -2.207658    0.279663   -0.866898    0.245868
# B   -1.234115   -1.159939   -0.144848    0.390494    0.092457   -0.930582
# C   -1.909958    0.235535   -1.189270    0.711756   -0.333655   -0.915743
# D    0.092016    0.599597    0.482793    0.305323   -0.372080   -1.808666
# ...

# %%
#Sorting by an axis:😜
df.sort_index(axis=1, ascending=True)
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-01  0.323613 -0.736972  0.003152 -0.707786  0.233113  0.237354
# 2021-01-02 -0.678482  1.955107 -0.788801  1.157041  0.760486  0.286319
# 2021-01-03 -0.590769 -1.605737  1.749867 -0.207156 -0.601891  0.041785
# 2021-01-04  0.250947  1.503697  0.245543  0.273735 -0.051535  0.528398
# 2021-01-05 -1.033194 -1.348296 -0.539497 -0.384510 -1.143572 -0.757063
# 2021-01-06 -0.128781  0.342956 -2.756559  0.515014  1.406602  1.841216
# 2021-01-07 -0.259941 -1.234115 -1.909958  0.092016  0.217133 -0.714602
# 2021-01-08  0.520155 -1.159939  0.235535  0.599597 -1.516344  0.949098
# 2021-01-09 -2.207658 -0.144848 -1.189270  0.482793  1.434138 -0.042195
# 2021-01-10  0.279663  0.390494  0.711756  0.305323 -0.733493 -0.050262
# 2021-01-11 -0.866898  0.092457 -0.333655 -0.372080  1.776262  0.748067
# 2021-01-12  0.245868 -0.930582 -0.915743 -1.808666  1.210387  0.453452
# ...

# %%
df.sort_index(axis=1, ascending=False)
# Out:
#                    G         F         E         D         C         B  \
# 2021-01-01 -1.888826  0.237354  0.233113 -0.707786  0.003152 -0.736972
# 2021-01-02 -0.966348  0.286319  0.760486  1.157041 -0.788801  1.955107
# 2021-01-03 -0.865228  0.041785 -0.601891 -0.207156  1.749867 -1.605737
# 2021-01-04  1.416893  0.528398 -0.051535  0.273735  0.245543  1.503697
# 2021-01-05 -0.575588 -0.757063 -1.143572 -0.384510 -0.539497 -1.348296
# 2021-01-06  0.887801  1.841216  1.406602  0.515014 -2.756559  0.342956
# 2021-01-07  0.092244 -0.714602  0.217133  0.092016 -1.909958 -1.234115
# 2021-01-08  0.152899  0.949098 -1.516344  0.599597  0.235535 -1.159939
# 2021-01-09  1.953434 -0.042195  1.434138  0.482793 -1.189270 -0.144848
# 2021-01-10 -0.169646 -0.050262 -0.733493  0.305323  0.711756  0.390494
# 2021-01-11 -1.576071  0.748067  1.776262 -0.372080 -0.333655  0.092457
# 2021-01-12  0.966738  0.453452  1.210387 -1.808666 -0.915743 -0.930582
# ...

# %%
#Sorting by values:
df.sort_values(by="B")
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-03 -0.590769 -1.605737  1.749867 -0.207156 -0.601891  0.041785
# 2021-01-05 -1.033194 -1.348296 -0.539497 -0.384510 -1.143572 -0.757063
# 2021-01-07 -0.259941 -1.234115 -1.909958  0.092016  0.217133 -0.714602
# 2021-01-08  0.520155 -1.159939  0.235535  0.599597 -1.516344  0.949098
# 2021-01-12  0.245868 -0.930582 -0.915743 -1.808666  1.210387  0.453452
# 2021-01-01  0.323613 -0.736972  0.003152 -0.707786  0.233113  0.237354
# 2021-01-09 -2.207658 -0.144848 -1.189270  0.482793  1.434138 -0.042195
# 2021-01-15  0.088490  0.086556 -1.283679 -1.100699 -1.494143  1.262776
# 2021-01-11 -0.866898  0.092457 -0.333655 -0.372080  1.776262  0.748067
# 2021-01-14  1.498963  0.181241  0.145791  0.608643 -0.837329  1.485074
# 2021-01-06 -0.128781  0.342956 -2.756559  0.515014  1.406602  1.841216
# 2021-01-10  0.279663  0.390494  0.711756  0.305323 -0.733493 -0.050262
# ...

# %%
#Selection,😜
#While standard Python / Numpy expressions for selecting and setting are intuitive and come in handy for interactive work, for production code, we recommend the optimized pandas data access methods, .at, .iat, .loc and .iloc.
# Getting by []
df[["A", "B"]]  #df["A"]
# Out:
#                    A         B
# 2021-01-01  0.323613 -0.736972
# 2021-01-02 -0.678482  1.955107
# 2021-01-03 -0.590769 -1.605737
# 2021-01-04  0.250947  1.503697
# 2021-01-05 -1.033194 -1.348296
# 2021-01-06 -0.128781  0.342956
# 2021-01-07 -0.259941 -1.234115
# 2021-01-08  0.520155 -1.159939
# 2021-01-09 -2.207658 -0.144848
# 2021-01-10  0.279663  0.390494
# 2021-01-11 -0.866898  0.092457
# 2021-01-12  0.245868 -0.930582
# 2021-01-13 -1.390649  1.076054
# 2021-01-14  1.498963  0.181241
# 2021-01-15  0.088490  0.086556

# %%
#range
df[0:5]
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-01  0.323613 -0.736972  0.003152 -0.707786  0.233113  0.237354
# 2021-01-02 -0.678482  1.955107 -0.788801  1.157041  0.760486  0.286319
# 2021-01-03 -0.590769 -1.605737  1.749867 -0.207156 -0.601891  0.041785
# 2021-01-04  0.250947  1.503697  0.245543  0.273735 -0.051535  0.528398
# 2021-01-05 -1.033194 -1.348296 -0.539497 -0.384510 -1.143572 -0.757063
#
#                    G
# 2021-01-01 -1.888826
# 2021-01-02 -0.966348
# 2021-01-03 -0.865228
# 2021-01-04  1.416893
# 2021-01-05 -0.575588

# %%
#range
df[7:9]
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-08  0.520155 -1.159939  0.235535  0.599597 -1.516344  0.949098
# 2021-01-09 -2.207658 -0.144848 -1.189270  0.482793  1.434138 -0.042195
#
#                    G
# 2021-01-08  0.152899
# 2021-01-09  1.953434

# %%
#Range
df["20210105":"20210108"]
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-05 -1.033194 -1.348296 -0.539497 -0.384510 -1.143572 -0.757063
# 2021-01-06 -0.128781  0.342956 -2.756559  0.515014  1.406602  1.841216
# 2021-01-07 -0.259941 -1.234115 -1.909958  0.092016  0.217133 -0.714602
# 2021-01-08  0.520155 -1.159939  0.235535  0.599597 -1.516344  0.949098
#
#                    G
# 2021-01-05 -0.575588
# 2021-01-06  0.887801
# 2021-01-07  0.092244
# 2021-01-08  0.152899

# %%
##Selection by label😜
df.loc[dates[0]]
# Out:
# A    0.323613
# B   -0.736972
# C    0.003152
# D   -0.707786
# E    0.233113
# F    0.237354
# G   -1.888826
# Name: 2021-01-01 00:00:00, dtype: float64

# %%
df.loc[dates[0]:dates[1]]
# Out:
#                    A         B         C         D         E         F  \
# 2021-01-01  0.323613 -0.736972  0.003152 -0.707786  0.233113  0.237354
# 2021-01-02 -0.678482  1.955107 -0.788801  1.157041  0.760486  0.286319
#
#                    G
# 2021-01-01 -1.888826
# 2021-01-02 -0.966348

# %%
#multiaxis
df.loc[:, ["A", "B"]]
# Out:
#                    A         B
# 2021-01-01  0.323613 -0.736972
# 2021-01-02 -0.678482  1.955107
# 2021-01-03 -0.590769 -1.605737
# 2021-01-04  0.250947  1.503697
# 2021-01-05 -1.033194 -1.348296
# 2021-01-06 -0.128781  0.342956
# 2021-01-07 -0.259941 -1.234115
# 2021-01-08  0.520155 -1.159939
# 2021-01-09 -2.207658 -0.144848
# 2021-01-10  0.279663  0.390494
# 2021-01-11 -0.866898  0.092457
# 2021-01-12  0.245868 -0.930582
# 2021-01-13 -1.390649  1.076054
# 2021-01-14  1.498963  0.181241
# 2021-01-15  0.088490  0.086556

# %%
df.loc["20210102":"20210104", ["A", "B"]] #only range
# Out:
#                    A         B
# 2021-01-02 -0.678482  1.955107
# 2021-01-03 -0.590769 -1.605737
# 2021-01-04  0.250947  1.503697
